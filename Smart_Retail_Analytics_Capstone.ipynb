# %% [markdown]
# # Smart Retail Analytics System --
#
# ## Capstone Project – Computer Vision for Developers with Ultralytics
#
# This project builds an end-to-end computer vision system for retail analytics using Ultralytics YOLO.
#
# The system performs object detection and video analytics to support real-world retail scenarios such as customer counting, heatmap generation, privacy protection, and video analytics.
#
# ### Main Objectives
#
# - Perform YOLO object detection.
# - Apply a vision task beyond basic detection.
# - Analyze customer movement using video analytics.
# - Evaluate model performance using validation metrics.
# - Fine-tune a YOLO model on a custom dataset.
# - Export the trained model to an optimized format.
#
# ### Technologies
#
# - Python
# - Ultralytics YOLO
# - OpenCV
# - NumPy
# - Google Colab
#
#
# #### **Developed by:** Saja Aljamal

# %% [markdown]
# ## 1. Project Setup
# ### 1.1 Install Ultralytics
#
# This section prepares the environment and installs the Ultralytics package required to build and run the computer vision pipeline.

# %%
# Install Ultralytics
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 47.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 2.3 MB/s eta 0:00:00

# %% [markdown]
# ### 1.2 Import Required Libraries
#
# The following libraries are imported for model inference, video processing, data handling, and the implementation of Ultralytics solutions.

# %%
from ultralytics import YOLO, solutions
import cv2
import os
import pandas as pd

print("Ultralytics and required libraries imported successfully!")
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics and required libraries imported successfully!

# %% [markdown]
# ## 2. YOLO Object Detection
# ### 2.1 Load YOLO Model
#
# In this section, a pretrained YOLO model is loaded and used to perform object detection on an input image.
# The model identifies objects in the image and returns bounding boxes, class labels, and confidence scores.
# This step demonstrates the basic YOLO inference pipeline before applying the model to the retail analytics tasks.

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model
model = YOLO("yolo26n.pt")

print("Model loaded successfully!")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 195.5MB/s 0.0s
# Model loaded successfully!

# %% [markdown]
# ### Observation
#
# The pretrained YOLO model was loaded successfully and is ready for inference.

# %% [markdown]
# ### 2.2 Run YOLO Inference
# The loaded YOLO model is now used to perform inference on an input image.
# The resulting image will contain bounding boxes around detected objects, along with their class labels and confidence scores.

# %%
import cv2

video_path = "solutions_ci_demo.mp4"
image_path = "detection_test_frame.jpg"

cap = cv2.VideoCapture(video_path)

success, frame = cap.read()

if not success:
    raise RuntimeError("Could not read the input video.")

cv2.imwrite(image_path, frame)

cap.release()

print("Test frame saved as:", image_path)
# Out:
# Test frame saved as: detection_test_frame.jpg

# %% [markdown]
# ### Run Detection on the Extracted Frame
# The extracted test frame is passed to the pretrained YOLO model to detect objects and generate bounding boxes, class labels, and confidence scores.

# %%
# Run YOLO inference
results = model(image_path)

# Generate annotated image
annotated_image = results[0].plot()

# Save the detection result
detection_output = "detection_result.jpg"
cv2.imwrite(detection_output, annotated_image)

print("Detection completed successfully!")
print("Output saved as:", detection_output)
# Out:
# image 1/1 /content/detection_test_frame.jpg: 384x640 19 persons, 466.4ms
# Speed: 4.0ms preprocess, 466.4ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
# Detection completed successfully!
# Output saved as: detection_result.jpg

# %% [markdown]
# ### Observation
#
# The YOLO model successfully detected objects in the test frame and generated an annotated image containing bounding boxes, class labels, and confidence scores.
#
# This confirms that the basic YOLO object detection inference pipeline is working correctly.

# %% [markdown]
# ## 3. Image Segmentation
#
# In this section, YOLO segmentation is used as a vision task beyond basic object detection.
#
# Unlike object detection, which represents an object using a bounding box, segmentation identifies the pixels belonging to each detected object using a segmentation mask.
#
# This provides more detailed information about the shape and location of objects in the scene.

# %% [markdown]
# ### 3.1 Load Segmentation Model
#
# A pretrained YOLO segmentation model is loaded to perform instance segmentation on the test frame.

# %%
from ultralytics import YOLO

# Load a pretrained YOLO segmentation model
segmentation_model = YOLO("yolo26n-seg.pt")

print("Segmentation model loaded successfully!")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n-seg.pt to 'yolo26n-seg.pt': 100% ━━━━━━━━━━━━ 6.4MB 206.3MB/s 0.0s
# Segmentation model loaded successfully!

# %% [markdown]
# ### 3.2 Run Segmentation
#
# The same test frame used for object detection is passed to the YOLO segmentation model.
#
# The model generates segmentation masks for the detected objects, providing a more detailed representation of each object than bounding boxes alone.

# %%
# Run segmentation on the test frame
segmentation_results = segmentation_model(image_path)

# Generate the annotated segmentation image
segmented_image = segmentation_results[0].plot()

# Save the segmentation result
segmentation_output = "segmentation_result.jpg"
cv2.imwrite(segmentation_output, segmented_image)

print("Segmentation completed successfully!")
print("Output saved as:", segmentation_output)
# Out:
# image 1/1 /content/detection_test_frame.jpg: 384x640 12 persons, 278.1ms
# Speed: 2.8ms preprocess, 278.1ms inference, 24.5ms postprocess per image at shape (1, 3, 384, 640)
# Segmentation completed successfully!
# Output saved as: segmentation_result.jpg

# %% [markdown]
# ### Observation
#
# The YOLO segmentation model successfully identified objects in the test frame and generated segmentation masks.
#
# The masks provide more detailed spatial information about the detected objects compared with bounding boxes alone. This demonstrates a computer vision task beyond basic object detection.

# %% [markdown]
# ## 4. Video Analytics
#
# This section applies Ultralytics Solutions to the retail video to perform real-world video analytics.
#
# The system includes customer counting, movement heatmap generation, privacy protection through object blurring, and video analytics.
#
# ### 4.1 People Counting
#
# The YOLO ObjectCounter solution is used to track people and count customers crossing a defined horizontal line.
#
# Only the person class is considered, and the BoT-SORT tracker is used to maintain object identities across video frames.

# %%
from ultralytics import solutions
import cv2
import os

video_path = "solutions_ci_demo.mp4"
output_path = "people_counting_result.mp4"

cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

if fps <= 0:
    fps = 30

fourcc = cv2.VideoWriter_fourcc(*"mp4v")

out = cv2.VideoWriter(
    output_path,
    fourcc,
    fps,
    (width, height)
)

counter = solutions.ObjectCounter(
    model="yolo26n.pt",
    classes=[0],
    region=[(50, 200), (590, 200)],
    show=False,
    tracker="botsort.yaml"
)

frame_count = 0

while cap.isOpened():

    success, frame = cap.read()

    if not success:
        break

    result = counter(frame)

    out.write(result.plot_im)

    frame_count += 1

cap.release()
out.release()

print("People counting completed!")
print("Frames processed:", frame_count)
print("Output saved as:", output_path)
print("IN:", counter.in_count)
print("OUT:", counter.out_count)
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo26n.pt', 'classes': [0], 'show_conf': True, 'show_labels': True, 'show_boxes': True, 'region': [(50, 200), (590, 200)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': False, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'quantize': None, 'imgsz': 640, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 2 packages in 228ms
# Prepared 1 package in 51ms
# Installed 1 package in 1ms
#  + lap==0.5.13
#
# requirements: AutoUpdate success ✅ 1.0s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# 0: 640x640 11.0ms, 18 person
# Speed: 1325.2ms track, 11.0ms solution per image at shape (1, 3, 640, 640)
#
# 1: 640x640 3.8ms, 18 person
# Speed: 167.6ms track, 3.8ms solution per image at shape (1, 3, 640, 640)
#
# 2: 640x640 3.4ms, 16 person
# Speed: 138.5ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 3: 640x640 3.3ms, 17 person
# Speed: 134.3ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 4: 640x640 3.3ms, 17 person
# Speed: 157.2ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 5: 640x640 3.2ms, 17 person
# Speed: 134.7ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 6: 640x640 3.3ms, 18 person
# Speed: 155.6ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 7: 640x640 3.3ms, 17 person
# Speed: 141.2ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 8: 640x640 5.4ms, 18 person
# Speed: 136.1ms track, 5.4ms solution per image at shape (1, 3, 640, 640)
#
# 9: 640x640 4.0ms, 22 person
# Speed: 135.5ms track, 4.0ms solution per image at shape (1, 3, 640, 640)
#
# 10: 640x640 4.7ms, 22 person
# Speed: 142.6ms track, 4.7ms solution per image at shape (1, 3, 640, 640)
#
# 11: 640x640 3.7ms, 20 person
# Speed: 140.3ms track, 3.7ms solution per image at shape (1, 3, 640, 640)
#
# 12: 640x640 3.6ms, 19 person
# Speed: 137.0ms track, 3.6ms solution per image at shape (1, 3, 640, 640)
#
# 13: 640x640 3.8ms, 20 person
# Speed: 155.9ms track, 3.8ms solution per image at shape (1, 3, 640, 640)
#
# 14: 640x640 3.7ms, 19 person
# Speed: 146.6ms track, 3.7ms solution per image at shape (1, 3, 640, 640)
#
# 15: 640x640 14.3ms, 20 person
# Speed: 139.9ms track, 14.3ms solution per image at shape (1, 3, 640, 640)
#
# 16: 640x640 3.9ms, 18 person
# Speed: 137.6ms track, 3.9ms solution per image at shape (1, 3, 640, 640)
#
# 17: 640x640 3.3ms, 16 person
# Speed: 141.6ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 18: 640x640 3.9ms, 17 person
# Speed: 134.7ms track, 3.9ms solution per image at shape (1, 3, 640, 640)
#
# 19: 640x640 5.7ms, 17 person
# Speed: 145.3ms track, 5.7ms solution per image at shape (1, 3, 640, 640)
#
# 20: 640x640 3.6ms, 17 person
# Speed: 151.8ms track, 3.6ms solution per image at shape (1, 3, 640, 640)
#
# 21: 640x640 3.4ms, 18 person
# Speed: 134.6ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 22: 640x640 3.3ms, 18 person
# Speed: 134.2ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 23: 640x640 3.3ms, 18 person
# Speed: 134.5ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 24: 640x640 3.3ms, 16 person
# Speed: 137.4ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 25: 640x640 3.1ms, 16 person
# Speed: 133.8ms track, 3.1ms solution per image at shape (1, 3, 640, 640)
#
# 26: 640x640 5.8ms, 17 person
# Speed: 150.8ms track, 5.8ms solution per image at shape (1, 3, 640, 640)
#
# 27: 640x640 3.2ms, 17 person
# Speed: 152.4ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 28: 640x640 3.1ms, 16 person
# Speed: 135.1ms track, 3.1ms solution per image at shape (1, 3, 640, 640)
#
# 29: 640x640 3.0ms, 16 person
# Speed: 130.6ms track, 3.0ms solution per image at shape (1, 3, 640, 640)
#
# 30: 640x640 2.8ms, 14 person
# Speed: 134.1ms track, 2.8ms solution per image at shape (1, 3, 640, 640)
#
# 31: 640x640 2.8ms, 14 person
# Speed: 132.2ms track, 2.8ms solution per image at shape (1, 3, 640, 640)
#
# 32: 640x640 3.1ms, 14 person
# Speed: 135.1ms track, 3.1ms solution per image at shape (1, 3, 640, 640)
#
# 33: 640x640 4.7ms, 14 person
# Speed: 146.4ms track, 4.7ms solution per image at shape (1, 3, 640, 640)
#
# 34: 640x640 2.8ms, 14 person
# Speed: 151.7ms track, 2.8ms solution per image at shape (1, 3, 640, 640)
#
# 35: 640x640 2.9ms, 13 person
# Speed: 134.6ms track, 2.9ms solution per image at shape (1, 3, 640, 640)
#
# 36: 640x640 2.8ms, 14 person
# Speed: 130.4ms track, 2.8ms solution per image at shape (1, 3, 640, 640)
#
# 37: 640x640 2.8ms, 14 person
# Speed: 135.2ms track, 2.8ms solution per image at shape (1, 3, 640, 640)
#
# 38: 640x640 2.9ms, 14 person
# Speed: 134.3ms track, 2.9ms solution per image at shape (1, 3, 640, 640)
#
# 39: 640x640 3.7ms, 12 person
# Speed: 140.3ms track, 3.7ms solution per image at shape (1, 3, 640, 640)
#
# 40: 640x640 3.1ms, 11 person
# Speed: 145.7ms track, 3.1ms solution per image at shape (1, 3, 640, 640)
#
# 41: 640x640 3.8ms, 16 person
# Speed: 150.6ms track, 3.8ms solution per image at shape (1, 3, 640, 640)
#
# 42: 640x640 3.2ms, 16 person
# Speed: 133.8ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 43: 640x640 3.2ms, 16 person
# Speed: 131.6ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 44: 640x640 3.2ms, 17 person
# Speed: 137.2ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 45: 640x640 3.2ms, 17 person
# Speed: 135.7ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 46: 640x640 3.5ms, 18 person
# Speed: 141.1ms track, 3.5ms solution per image at shape (1, 3, 640, 640)
#
# 47: 640x640 3.4ms, 18 person
# Speed: 142.3ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 48: 640x640 5.2ms, 19 person
# Speed: 231.3ms track, 5.2ms solution per image at shape (1, 3, 640, 640)
#
# 49: 640x640 5.5ms, 20 person
# Speed: 209.8ms track, 5.5ms solution per image at shape (1, 3, 640, 640)
#
# 50: 640x640 7.5ms, 17 person
# Speed: 207.4ms track, 7.5ms solution per image at shape (1, 3, 640, 640)
#
# 51: 640x640 4.9ms, 18 person
# Speed: 209.9ms track, 4.9ms solution per image at shape (1, 3, 640, 640)
#
# 52: 640x640 5.3ms, 17 person
# Speed: 226.7ms track, 5.3ms solution per image at shape (1, 3, 640, 640)
#
# 53: 640x640 5.0ms, 18 person
# Speed: 210.5ms track, 5.0ms solution per image at shape (1, 3, 640, 640)
#
# 54: 640x640 5.1ms, 19 person
# Speed: 200.2ms track, 5.1ms solution per image at shape (1, 3, 640, 640)
#
# 55: 640x640 6.0ms, 19 person
# Speed: 198.1ms track, 6.0ms solution per image at shape (1, 3, 640, 640)
#
# 56: 640x640 4.5ms, 17 person
# Speed: 212.0ms track, 4.5ms solution per image at shape (1, 3, 640, 640)
#
# 57: 640x640 6.4ms, 18 person
# Speed: 212.8ms track, 6.4ms solution per image at shape (1, 3, 640, 640)
#
# 58: 640x640 4.9ms, 18 person
# Speed: 212.1ms track, 4.9ms solution per image at shape (1, 3, 640, 640)
#
# 59: 640x640 4.7ms, 17 person
# Speed: 205.6ms track, 4.7ms solution per image at shape (1, 3, 640, 640)
#
# 60: 640x640 6.1ms, 18 person
# Speed: 203.7ms track, 6.1ms solution per image at shape (1, 3, 640, 640)
#
# 61: 640x640 6.0ms, 19 person
# Speed: 209.5ms track, 6.0ms solution per image at shape (1, 3, 640, 640)
#
# People counting completed!
# Frames processed: 62
# Output saved as: people_counting_result.mp4
# IN: 3
# OUT: 1

# %% [markdown]
# ### Observation
#
# The ObjectCounter successfully tracked people in the video and counted objects crossing the defined counting line.
#
# The resulting video contains the detected people, bounding boxes, tracking information, and the IN/OUT counter.

# %% [markdown]
# ### 4.2 Heatmap
#
# The YOLO Heatmap solution is used to visualize areas with higher levels of person activity.
#
# The heatmap helps identify frequently visited areas and can provide useful information about customer movement and popular zones inside a retail environment.

# %%
from ultralytics import solutions
import cv2

video_path = "solutions_ci_demo.mp4"
output_path = "heatmap_result.mp4"

cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

if fps <= 0:
    fps = 30

fourcc = cv2.VideoWriter_fourcc(*"mp4v")

out = cv2.VideoWriter(
    output_path,
    fourcc,
    fps,
    (width, height)
)

heatmap = solutions.Heatmap(
    model="yolo26n.pt",
    classes=[0],
    show=False
)

frame_count = 0

while cap.isOpened():

    success, frame = cap.read()

    if not success:
        break

    result = heatmap(frame)

    out.write(result.plot_im)

    frame_count += 1

cap.release()
out.release()

print("Heatmap completed!")
print("Frames processed:", frame_count)
print("Output saved as:", output_path)
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo26n.pt', 'classes': [0], 'show_conf': True, 'show_labels': True, 'show_boxes': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': False, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'quantize': None, 'imgsz': 640, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 640x640 12.6ms, 18 person
# Speed: 158.8ms track, 12.6ms solution per image at shape (1, 3, 640, 640)
#
# 1: 640x640 5.2ms, 18 person
# Speed: 141.0ms track, 5.2ms solution per image at shape (1, 3, 640, 640)
#
# 2: 640x640 3.3ms, 16 person
# Speed: 141.9ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 3: 640x640 3.4ms, 17 person
# Speed: 140.9ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 4: 640x640 3.4ms, 17 person
# Speed: 135.3ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 5: 640x640 5.3ms, 17 person
# Speed: 186.4ms track, 5.3ms solution per image at shape (1, 3, 640, 640)
#
# 6: 640x640 4.6ms, 18 person
# Speed: 214.1ms track, 4.6ms solution per image at shape (1, 3, 640, 640)
#
# 7: 640x640 6.7ms, 17 person
# Speed: 218.9ms track, 6.7ms solution per image at shape (1, 3, 640, 640)
#
# 8: 640x640 5.3ms, 18 person
# Speed: 231.5ms track, 5.3ms solution per image at shape (1, 3, 640, 640)
#
# 9: 640x640 5.0ms, 22 person
# Speed: 208.5ms track, 5.0ms solution per image at shape (1, 3, 640, 640)
#
# 10: 640x640 5.4ms, 22 person
# Speed: 206.6ms track, 5.4ms solution per image at shape (1, 3, 640, 640)
#
# 11: 640x640 5.8ms, 20 person
# Speed: 200.2ms track, 5.8ms solution per image at shape (1, 3, 640, 640)
#
# 12: 640x640 6.1ms, 19 person
# Speed: 220.3ms track, 6.1ms solution per image at shape (1, 3, 640, 640)
#
# 13: 640x640 4.9ms, 20 person
# Speed: 204.3ms track, 4.9ms solution per image at shape (1, 3, 640, 640)
#
# 14: 640x640 5.9ms, 19 person
# Speed: 202.9ms track, 5.9ms solution per image at shape (1, 3, 640, 640)
#
# 15: 640x640 4.8ms, 20 person
# Speed: 214.4ms track, 4.8ms solution per image at shape (1, 3, 640, 640)
#
# 16: 640x640 4.6ms, 18 person
# Speed: 206.5ms track, 4.6ms solution per image at shape (1, 3, 640, 640)
#
# 17: 640x640 5.1ms, 16 person
# Speed: 233.5ms track, 5.1ms solution per image at shape (1, 3, 640, 640)
#
# 18: 640x640 5.4ms, 17 person
# Speed: 224.7ms track, 5.4ms solution per image at shape (1, 3, 640, 640)
#
# 19: 640x640 5.0ms, 17 person
# Speed: 211.8ms track, 5.0ms solution per image at shape (1, 3, 640, 640)
#
# 20: 640x640 3.2ms, 17 person
# Speed: 156.2ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 21: 640x640 3.4ms, 18 person
# Speed: 140.6ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 22: 640x640 3.4ms, 18 person
# Speed: 153.7ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 23: 640x640 3.4ms, 18 person
# Speed: 159.4ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 24: 640x640 3.4ms, 16 person
# Speed: 140.4ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 25: 640x640 3.5ms, 16 person
# Speed: 132.3ms track, 3.5ms solution per image at shape (1, 3, 640, 640)
#
# 26: 640x640 3.8ms, 17 person
# Speed: 137.3ms track, 3.8ms solution per image at shape (1, 3, 640, 640)
#
# 27: 640x640 6.2ms, 17 person
# Speed: 132.7ms track, 6.2ms solution per image at shape (1, 3, 640, 640)
#
# 28: 640x640 3.3ms, 16 person
# Speed: 141.4ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 29: 640x640 4.2ms, 16 person
# Speed: 143.0ms track, 4.2ms solution per image at shape (1, 3, 640, 640)
#
# 30: 640x640 3.1ms, 14 person
# Speed: 158.5ms track, 3.1ms solution per image at shape (1, 3, 640, 640)
#
# 31: 640x640 3.2ms, 14 person
# Speed: 134.9ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 32: 640x640 3.1ms, 14 person
# Speed: 137.1ms track, 3.1ms solution per image at shape (1, 3, 640, 640)
#
# 33: 640x640 3.1ms, 14 person
# Speed: 142.2ms track, 3.1ms solution per image at shape (1, 3, 640, 640)
#
# 34: 640x640 4.0ms, 14 person
# Speed: 141.5ms track, 4.0ms solution per image at shape (1, 3, 640, 640)
#
# 35: 640x640 2.9ms, 13 person
# Speed: 143.8ms track, 2.9ms solution per image at shape (1, 3, 640, 640)
#
# 36: 640x640 3.0ms, 14 person
# Speed: 150.2ms track, 3.0ms solution per image at shape (1, 3, 640, 640)
#
# 37: 640x640 4.2ms, 14 person
# Speed: 150.8ms track, 4.2ms solution per image at shape (1, 3, 640, 640)
#
# 38: 640x640 3.2ms, 14 person
# Speed: 134.3ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 39: 640x640 3.0ms, 12 person
# Speed: 138.6ms track, 3.0ms solution per image at shape (1, 3, 640, 640)
#
# 40: 640x640 2.7ms, 11 person
# Speed: 134.8ms track, 2.7ms solution per image at shape (1, 3, 640, 640)
#
# 41: 640x640 3.2ms, 16 person
# Speed: 136.6ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 42: 640x640 3.2ms, 16 person
# Speed: 146.9ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 43: 640x640 3.2ms, 16 person
# Speed: 133.0ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 44: 640x640 3.3ms, 17 person
# Speed: 151.0ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 45: 640x640 3.2ms, 17 person
# Speed: 132.8ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 46: 640x640 3.4ms, 18 person
# Speed: 137.7ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 47: 640x640 3.3ms, 18 person
# Speed: 134.4ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 48: 640x640 3.5ms, 19 person
# Speed: 136.3ms track, 3.5ms solution per image at shape (1, 3, 640, 640)
#
# 49: 640x640 4.6ms, 20 person
# Speed: 140.4ms track, 4.6ms solution per image at shape (1, 3, 640, 640)
#
# 50: 640x640 3.2ms, 17 person
# Speed: 135.5ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 51: 640x640 3.3ms, 18 person
# Speed: 149.1ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 52: 640x640 3.3ms, 17 person
# Speed: 134.8ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 53: 640x640 3.4ms, 18 person
# Speed: 134.5ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 54: 640x640 3.4ms, 19 person
# Speed: 135.6ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 55: 640x640 3.5ms, 19 person
# Speed: 145.3ms track, 3.5ms solution per image at shape (1, 3, 640, 640)
#
# 56: 640x640 3.3ms, 17 person
# Speed: 151.6ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 57: 640x640 3.5ms, 18 person
# Speed: 144.1ms track, 3.5ms solution per image at shape (1, 3, 640, 640)
#
# 58: 640x640 3.3ms, 18 person
# Speed: 154.9ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 59: 640x640 3.4ms, 17 person
# Speed: 137.7ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 60: 640x640 3.4ms, 18 person
# Speed: 136.2ms track, 3.4ms solution per image at shape (1, 3, 640, 640)
#
# 61: 640x640 3.9ms, 19 person
# Speed: 132.9ms track, 3.9ms solution per image at shape (1, 3, 640, 640)
#
# Heatmap completed!
# Frames processed: 62
# Output saved as: heatmap_result.mp4

# %% [markdown]
# ### Observation
#
# The Heatmap solution successfully visualized the movement of detected people throughout the video.
#
# The resulting heatmap highlights areas where people were more frequently present or active, which can help identify popular zones in a retail environment.

# %% [markdown]
# ### 4.3 Object Blurring
#
# The YOLO ObjectBlurrer solution is used to blur detected people in the video.
#
# This provides a simple privacy-preserving approach by obscuring customer identities while maintaining the usefulness of the video for analytics.

# %%
from ultralytics import solutions
import cv2

video_path = "solutions_ci_demo.mp4"
output_path = "blurred_result.mp4"

cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

if fps <= 0:
    fps = 30

fourcc = cv2.VideoWriter_fourcc(*"mp4v")

out = cv2.VideoWriter(
    output_path,
    fourcc,
    fps,
    (width, height)
)

blurrer = solutions.ObjectBlurrer(
    model="yolo26n.pt",
    classes=[0],
    blur_ratio=0.5,
    show=False
)

frame_count = 0

while cap.isOpened():

    success, frame = cap.read()

    if not success:
        break

    result = blurrer(frame)

    out.write(result.plot_im)

    frame_count += 1

cap.release()
out.release()

print("Object blurring completed!")
print("Frames processed:", frame_count)
print("Output saved as:", output_path)
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo26n.pt', 'classes': [0], 'show_conf': True, 'show_labels': True, 'show_boxes': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': False, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'quantize': None, 'imgsz': 640, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 640x640 3.6ms, 18 person
# Speed: 177.2ms track, 3.6ms solution per image at shape (1, 3, 640, 640)
#
# 1: 640x640 5.1ms, 18 person
# Speed: 147.4ms track, 5.1ms solution per image at shape (1, 3, 640, 640)
#
# 2: 640x640 2.3ms, 16 person
# Speed: 196.8ms track, 2.3ms solution per image at shape (1, 3, 640, 640)
#
# 3: 640x640 2.8ms, 17 person
# Speed: 145.8ms track, 2.8ms solution per image at shape (1, 3, 640, 640)
#
# 4: 640x640 2.2ms, 17 person
# Speed: 137.5ms track, 2.2ms solution per image at shape (1, 3, 640, 640)
#
# 5: 640x640 2.2ms, 17 person
# Speed: 137.7ms track, 2.2ms solution per image at shape (1, 3, 640, 640)
#
# 6: 640x640 2.4ms, 18 person
# Speed: 141.7ms track, 2.4ms solution per image at shape (1, 3, 640, 640)
#
# 7: 640x640 2.3ms, 17 person
# Speed: 137.4ms track, 2.3ms solution per image at shape (1, 3, 640, 640)
#
# 8: 640x640 2.5ms, 18 person
# Speed: 139.9ms track, 2.5ms solution per image at shape (1, 3, 640, 640)
#
# 9: 640x640 2.9ms, 22 person
# Speed: 163.2ms track, 2.9ms solution per image at shape (1, 3, 640, 640)
#
# 10: 640x640 2.9ms, 22 person
# Speed: 137.9ms track, 2.9ms solution per image at shape (1, 3, 640, 640)
#
# 11: 640x640 2.7ms, 20 person
# Speed: 134.7ms track, 2.7ms solution per image at shape (1, 3, 640, 640)
#
# 12: 640x640 2.8ms, 19 person
# Speed: 140.0ms track, 2.8ms solution per image at shape (1, 3, 640, 640)
#
# 13: 640x640 2.6ms, 20 person
# Speed: 135.5ms track, 2.6ms solution per image at shape (1, 3, 640, 640)
#
# 14: 640x640 2.5ms, 19 person
# Speed: 138.9ms track, 2.5ms solution per image at shape (1, 3, 640, 640)
#
# 15: 640x640 2.6ms, 20 person
# Speed: 144.9ms track, 2.6ms solution per image at shape (1, 3, 640, 640)
#
# 16: 640x640 2.4ms, 18 person
# Speed: 150.3ms track, 2.4ms solution per image at shape (1, 3, 640, 640)
#
# 17: 640x640 2.2ms, 16 person
# Speed: 136.8ms track, 2.2ms solution per image at shape (1, 3, 640, 640)
#
# 18: 640x640 2.3ms, 17 person
# Speed: 134.7ms track, 2.3ms solution per image at shape (1, 3, 640, 640)
#
# 19: 640x640 2.6ms, 17 person
# Speed: 141.1ms track, 2.6ms solution per image at shape (1, 3, 640, 640)
#
# 20: 640x640 2.9ms, 17 person
# Speed: 141.5ms track, 2.9ms solution per image at shape (1, 3, 640, 640)
#
# 21: 640x640 2.6ms, 18 person
# Speed: 149.3ms track, 2.6ms solution per image at shape (1, 3, 640, 640)
#
# 22: 640x640 3.7ms, 18 person
# Speed: 152.8ms track, 3.7ms solution per image at shape (1, 3, 640, 640)
#
# 23: 640x640 2.6ms, 18 person
# Speed: 143.4ms track, 2.6ms solution per image at shape (1, 3, 640, 640)
#
# 24: 640x640 2.2ms, 16 person
# Speed: 135.1ms track, 2.2ms solution per image at shape (1, 3, 640, 640)
#
# 25: 640x640 2.3ms, 16 person
# Speed: 137.1ms track, 2.3ms solution per image at shape (1, 3, 640, 640)
#
# 26: 640x640 2.4ms, 17 person
# Speed: 140.0ms track, 2.4ms solution per image at shape (1, 3, 640, 640)
#
# 27: 640x640 2.4ms, 17 person
# Speed: 139.5ms track, 2.4ms solution per image at shape (1, 3, 640, 640)
#
# 28: 640x640 3.0ms, 16 person
# Speed: 138.8ms track, 3.0ms solution per image at shape (1, 3, 640, 640)
#
# 29: 640x640 3.5ms, 16 person
# Speed: 146.3ms track, 3.5ms solution per image at shape (1, 3, 640, 640)
#
# 30: 640x640 2.3ms, 14 person
# Speed: 142.6ms track, 2.3ms solution per image at shape (1, 3, 640, 640)
#
# 31: 640x640 2.0ms, 14 person
# Speed: 135.6ms track, 2.0ms solution per image at shape (1, 3, 640, 640)
#
# 32: 640x640 2.2ms, 14 person
# Speed: 137.3ms track, 2.2ms solution per image at shape (1, 3, 640, 640)
#
# 33: 640x640 2.0ms, 14 person
# Speed: 142.2ms track, 2.0ms solution per image at shape (1, 3, 640, 640)
#
# 34: 640x640 2.1ms, 14 person
# Speed: 142.4ms track, 2.1ms solution per image at shape (1, 3, 640, 640)
#
# 35: 640x640 2.0ms, 13 person
# Speed: 154.8ms track, 2.0ms solution per image at shape (1, 3, 640, 640)
#
# 36: 640x640 2.5ms, 14 person
# Speed: 160.9ms track, 2.5ms solution per image at shape (1, 3, 640, 640)
#
# 37: 640x640 2.0ms, 14 person
# Speed: 136.7ms track, 2.0ms solution per image at shape (1, 3, 640, 640)
#
# 38: 640x640 2.0ms, 14 person
# Speed: 136.8ms track, 2.0ms solution per image at shape (1, 3, 640, 640)
#
# 39: 640x640 1.8ms, 12 person
# Speed: 153.5ms track, 1.8ms solution per image at shape (1, 3, 640, 640)
#
# 40: 640x640 2.6ms, 11 person
# Speed: 153.5ms track, 2.6ms solution per image at shape (1, 3, 640, 640)
#
# 41: 640x640 3.1ms, 16 person
# Speed: 219.9ms track, 3.1ms solution per image at shape (1, 3, 640, 640)
#
# 42: 640x640 4.1ms, 16 person
# Speed: 206.8ms track, 4.1ms solution per image at shape (1, 3, 640, 640)
#
# 43: 640x640 3.0ms, 16 person
# Speed: 206.5ms track, 3.0ms solution per image at shape (1, 3, 640, 640)
#
# 44: 640x640 3.2ms, 17 person
# Speed: 203.4ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 45: 640x640 3.2ms, 17 person
# Speed: 214.2ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 46: 640x640 3.3ms, 18 person
# Speed: 211.9ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 47: 640x640 4.1ms, 18 person
# Speed: 205.2ms track, 4.1ms solution per image at shape (1, 3, 640, 640)
#
# 48: 640x640 3.5ms, 19 person
# Speed: 201.9ms track, 3.5ms solution per image at shape (1, 3, 640, 640)
#
# 49: 640x640 3.7ms, 20 person
# Speed: 196.5ms track, 3.7ms solution per image at shape (1, 3, 640, 640)
#
# 50: 640x640 3.2ms, 17 person
# Speed: 204.0ms track, 3.2ms solution per image at shape (1, 3, 640, 640)
#
# 51: 640x640 3.3ms, 18 person
# Speed: 214.6ms track, 3.3ms solution per image at shape (1, 3, 640, 640)
#
# 52: 640x640 3.8ms, 17 person
# Speed: 207.5ms track, 3.8ms solution per image at shape (1, 3, 640, 640)
#
# 53: 640x640 4.1ms, 18 person
# Speed: 204.1ms track, 4.1ms solution per image at shape (1, 3, 640, 640)
#
# 54: 640x640 4.0ms, 19 person
# Speed: 214.1ms track, 4.0ms solution per image at shape (1, 3, 640, 640)
#
# 55: 640x640 3.8ms, 19 person
# Speed: 212.0ms track, 3.8ms solution per image at shape (1, 3, 640, 640)
#
# 56: 640x640 2.5ms, 17 person
# Speed: 166.2ms track, 2.5ms solution per image at shape (1, 3, 640, 640)
#
# 57: 640x640 2.4ms, 18 person
# Speed: 136.1ms track, 2.4ms solution per image at shape (1, 3, 640, 640)
#
# 58: 640x640 2.5ms, 18 person
# Speed: 155.8ms track, 2.5ms solution per image at shape (1, 3, 640, 640)
#
# 59: 640x640 3.0ms, 17 person
# Speed: 145.3ms track, 3.0ms solution per image at shape (1, 3, 640, 640)
#
# 60: 640x640 3.5ms, 18 person
# Speed: 137.2ms track, 3.5ms solution per image at shape (1, 3, 640, 640)
#
# 61: 640x640 2.6ms, 19 person
# Speed: 145.0ms track, 2.6ms solution per image at shape (1, 3, 640, 640)
#
# Object blurring completed!
# Frames processed: 62
# Output saved as: blurred_result.mp4

# %% [markdown]
# ### Observation
#
# The ObjectBlurrer successfully detected and blurred people in the video.
#
# The resulting video preserves the overall scene and object locations while reducing identifiable visual information, supporting privacy protection in a retail environment.

# %% [markdown]
# ### 4.4 Video Analytics
#
# The Ultralytics Analytics solution is used to analyze object movement across the video frames.
#
# The analytics output provides a visual representation of object activity over time, which can support understanding of customer movement patterns in a retail environment.

# %%
from ultralytics import solutions
import cv2

video_path = "solutions_ci_demo.mp4"
output_path = "analytics_result.mp4"

cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

if fps <= 0:
    fps = 30

fourcc = cv2.VideoWriter_fourcc(*"mp4v")

out = cv2.VideoWriter(
    output_path,
    fourcc,
    fps,
    (width, height)
)

analytics = solutions.Analytics(
    model="yolo26n.pt",
    classes=[0],
    analytics_type="line",
    tracker="botsort.yaml",
    show=False
)

frame_number = 0

while cap.isOpened():

    success, frame = cap.read()

    if not success:
        break

    result = analytics(frame, frame_number)

    processed_frame = result.plot_im

    processed_frame = cv2.resize(
        processed_frame,
        (width, height)
    )

    out.write(processed_frame)

    frame_number += 1

cap.release()
out.release()

print("Analytics completed!")
print("Frames processed:", frame_number)
print("Output saved as:", output_path)
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo26n.pt', 'classes': [0], 'show_conf': True, 'show_labels': True, 'show_boxes': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': False, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'quantize': None, 'imgsz': 640, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 640x640 103.0ms, 18 person
# Speed: 199.7ms track, 103.0ms solution per image at shape (1, 3, 640, 640)
#
# 1: 640x640 0.2ms, 18 person
# Speed: 138.2ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 2: 640x640 0.1ms, 16 person
# Speed: 142.3ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 3: 640x640 0.1ms, 17 person
# Speed: 139.3ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 4: 640x640 0.2ms, 17 person
# Speed: 146.6ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 5: 640x640 0.1ms, 17 person
# Speed: 141.8ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 6: 640x640 0.2ms, 18 person
# Speed: 138.5ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 7: 640x640 0.1ms, 17 person
# Speed: 140.7ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 8: 640x640 0.1ms, 18 person
# Speed: 133.0ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 9: 640x640 0.1ms, 22 person
# Speed: 139.4ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 10: 640x640 0.1ms, 22 person
# Speed: 135.1ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 11: 640x640 0.1ms, 20 person
# Speed: 139.6ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 12: 640x640 0.2ms, 19 person
# Speed: 140.7ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 13: 640x640 0.1ms, 20 person
# Speed: 133.3ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 14: 640x640 0.1ms, 19 person
# Speed: 148.1ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 15: 640x640 0.1ms, 20 person
# Speed: 137.7ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 16: 640x640 0.1ms, 18 person
# Speed: 136.5ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 17: 640x640 0.1ms, 16 person
# Speed: 138.2ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 18: 640x640 0.1ms, 17 person
# Speed: 146.3ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 19: 640x640 0.1ms, 17 person
# Speed: 149.3ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 20: 640x640 0.1ms, 17 person
# Speed: 137.0ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 21: 640x640 0.1ms, 18 person
# Speed: 154.4ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 22: 640x640 0.1ms, 18 person
# Speed: 138.9ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 23: 640x640 0.1ms, 18 person
# Speed: 139.2ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 24: 640x640 0.1ms, 16 person
# Speed: 136.1ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 25: 640x640 0.1ms, 16 person
# Speed: 146.3ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 26: 640x640 0.1ms, 17 person
# Speed: 143.0ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 27: 640x640 0.2ms, 17 person
# Speed: 164.8ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 28: 640x640 0.2ms, 16 person
# Speed: 229.7ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 29: 640x640 0.2ms, 16 person
# Speed: 202.8ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 30: 640x640 78.3ms, 14 person
# Speed: 207.9ms track, 78.3ms solution per image at shape (1, 3, 640, 640)
#
# 31: 640x640 0.2ms, 14 person
# Speed: 197.6ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 32: 640x640 0.3ms, 14 person
# Speed: 213.1ms track, 0.3ms solution per image at shape (1, 3, 640, 640)
#
# 33: 640x640 0.2ms, 14 person
# Speed: 215.8ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 34: 640x640 0.2ms, 14 person
# Speed: 208.5ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 35: 640x640 0.1ms, 13 person
# Speed: 203.9ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 36: 640x640 0.1ms, 14 person
# Speed: 194.7ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 37: 640x640 0.2ms, 14 person
# Speed: 197.4ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 38: 640x640 0.1ms, 14 person
# Speed: 223.3ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 39: 640x640 0.2ms, 12 person
# Speed: 213.5ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 40: 640x640 0.2ms, 11 person
# Speed: 213.1ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 41: 640x640 0.2ms, 16 person
# Speed: 210.1ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 42: 640x640 0.7ms, 16 person
# Speed: 218.9ms track, 0.7ms solution per image at shape (1, 3, 640, 640)
#
# 43: 640x640 0.1ms, 16 person
# Speed: 144.5ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 44: 640x640 0.1ms, 17 person
# Speed: 148.7ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 45: 640x640 0.1ms, 17 person
# Speed: 148.8ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 46: 640x640 0.1ms, 18 person
# Speed: 138.1ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 47: 640x640 0.2ms, 18 person
# Speed: 142.6ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 48: 640x640 0.1ms, 19 person
# Speed: 137.2ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 49: 640x640 0.2ms, 20 person
# Speed: 144.2ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 50: 640x640 0.1ms, 17 person
# Speed: 147.3ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 51: 640x640 0.1ms, 18 person
# Speed: 142.9ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 52: 640x640 0.1ms, 17 person
# Speed: 148.8ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 53: 640x640 0.1ms, 18 person
# Speed: 139.6ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 54: 640x640 0.1ms, 19 person
# Speed: 141.9ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 55: 640x640 0.1ms, 19 person
# Speed: 138.4ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 56: 640x640 0.2ms, 17 person
# Speed: 150.9ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 57: 640x640 0.1ms, 18 person
# Speed: 143.1ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 58: 640x640 0.2ms, 18 person
# Speed: 152.5ms track, 0.2ms solution per image at shape (1, 3, 640, 640)
#
# 59: 640x640 0.1ms, 17 person
# Speed: 146.4ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# 60: 640x640 50.2ms, 18 person
# Speed: 144.5ms track, 50.2ms solution per image at shape (1, 3, 640, 640)
#
# 61: 640x640 0.1ms, 19 person
# Speed: 133.8ms track, 0.1ms solution per image at shape (1, 3, 640, 640)
#
# Analytics completed!
# Frames processed: 62
# Output saved as: analytics_result.mp4

# %% [markdown]
# ### Observation
#
# The Analytics solution successfully processed the video and generated a visual representation of object activity across frames.
#
# The resulting video can be used to analyze customer movement patterns and activity within the retail environment.

# %% [markdown]
# ## 5. Model Evaluation
#
# This section evaluates the performance of the pretrained YOLO model using the validation dataset and standard object detection metrics.
#
# The evaluation provides quantitative measurements that help assess how accurately the model detects objects.

# %% [markdown]
# ### 5.1 Prepare Validation Dataset
#
# A validation dataset is required to quantitatively evaluate the pretrained YOLO model.
#
# The project uses a standard YOLO-format validation dataset so that the model can be evaluated using precision, recall, mAP50, and mAP50-95 metrics.

# %%
import os
import yaml
from ultralytics.utils import ASSETS

print("Ultralytics assets directory:", ASSETS)
# Out:
# Ultralytics assets directory: /usr/local/lib/python3.12/dist-packages/ultralytics/assets

# %%
from ultralytics import YOLO

model = YOLO("yolo26n.pt")

validation_results = model.val(
    data="coco8.yaml",
    imgsz=640,
    batch=8
)

print("Validation completed successfully!")
# Out:
# Ultralytics 8.4.118 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.5 GFLOPs
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/content/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/content/datasets/coco8.zip': 100% ━━━━━━━━━━━━ 432.8KB 63.5MB/s 0.0s
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 1.8Kfiles/s 0.0s
# Dataset download success ✅ (0.4s), saved to /content/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 99.6MB/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1076.1±492.5 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 52.7it/s 0.1s
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0s/it 1.0s
#                    all          4         17      0.849      0.654      0.906      0.665
#                 person          3         10          1      0.427      0.764      0.375
#                    dog          1          1      0.718          1      0.995      0.597
#                  horse          1          2        0.8          1      0.995      0.795
#               elephant          1          2      0.854        0.5      0.695       0.43
#               umbrella          1          1      0.724          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 8.1ms preprocess, 230.5ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /content/runs/detect/val-2
# Validation completed successfully!

# %% [markdown]
# ### 5.2 Evaluation Metrics
#
# The validation results are used to measure the object detection performance of the pretrained YOLO model.
#
# The main evaluation metrics are:
#
# - Precision: measures how many predicted detections are correct.
# - Recall: measures how many relevant objects were successfully detected.
# - mAP50: mean Average Precision at an IoU threshold of 0.50.
# - mAP50-95: mean Average Precision averaged across IoU thresholds from 0.50 to 0.95.

# %%
print("Precision:", validation_results.box.mp)
print("Recall:", validation_results.box.mr)
print("mAP50:", validation_results.box.map50)
print("mAP50-95:", validation_results.box.map)
# Out:
# Precision: 0.849132198371236
# Recall: 0.6544622776896057
# mAP50: 0.9064941894674905
# mAP50-95: 0.6647706555170674

# %% [markdown]
# ### 5.3 Interpretation
#
# The pretrained YOLO model was evaluated on the COCO8 validation dataset.
#
# The model achieved a Precision of 0.849, meaning that most of the predicted detections were correct. The Recall of 0.654 indicates that the model detected a substantial portion of the objects present in the validation images, while some objects were missed, resulting in false negatives.
#
# The mAP50 of 0.906 indicates strong detection performance when an IoU threshold of 0.50 is used. The mAP50-95 of 0.665 is lower because it evaluates detection quality across multiple IoU thresholds from 0.50 to 0.95 and is therefore more strict.
#
# For the retail use case, false negatives may occur when people are partially occluded, small, or difficult to distinguish from the background. False positives may occur when background regions or other objects are incorrectly classified as people.
#
# The confidence threshold controls how certain the model must be before accepting a detection, while the IoU threshold determines how much the predicted bounding box must overlap with the ground-truth box to be considered a correct detection.
#
# These validation results provide a quantitative baseline for the pretrained model before custom training on a task-specific retail dataset.

# %% [markdown]
# ### 5.4 Observation
#
# The validation process completed successfully using the COCO8 dataset.
#
# The results provide a quantitative baseline for the pretrained YOLO model. The model achieved strong Precision and mAP50 performance, while the lower Recall indicates that some objects were missed.
#
# Since COCO8 is a general-purpose validation dataset, these results should be considered a baseline rather than a direct measurement of performance on the project's retail environment.
